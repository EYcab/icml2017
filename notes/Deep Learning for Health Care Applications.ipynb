# %%
from IPython.display import Image

# %% [markdown]
# # [Deep Learning for Health Care Applications](https://sites.google.com/view/icml2017-deep-health-tutorial/home)
#
# Sun, 8/5/2017
#
# Yan Liu (USC)
#
# Jimeng Sun (Georgia Tech)
#
# *It is widely believed that deep learning and artificial intelligence techniques will fundamentally change healthcare industries. Even though recent development in deep learning has achieved successes in many applications, such as computer vision, natural language processing, speech recognition and so on, healthcare applications pose many significantly different challenges to existing deep learning models. __Examples include but not are limited to interpretations for prediction, heterogeneity in data, missing value, multi-rate multi-resolution data, big and small data, and privacy issues.__ In this tutorial, we will discuss a series of problems in healthcare that can benefit from deep learning models, the challenges as well as recent advances in addressing those. We will also include data sets and demos of working systems.*
#
# [(Slides)](http://www-bcf.usc.edu/~liu32/icml_tutorial.pdf)
#
# I took notes on the pieces that are pertinent to State Farm (claims, interpretable deep learning, etc.)

# %% [markdown]
# ## EHR and Claims Data
#
# #### - Predicting clinical events via recurrent neural networks
# - Similar to insurance claims, in healthcare most people currently would rather interact with a human than a machine
# - *Can machines perform similarly as doctors in diagnosis?*
#   - Treat patient visits as event sequences (i.e., recurrent neural network is appropriate)
#     - Hidden states become a representation of a patient visit (status of that visit and previous visits)
#     - Can handle sequences of variable length
#     - Could we do use a similar approach to things like call mitigation or claims routing?

# %% [markdown]
# ## Interpretable Deep Learning Models
#
# How can you trust a machine learning algorithm? For instance:

# %%
Image(filename='.img/dlhc.png')

# %% [markdown]
# We can't guarantee what a machine learning algorithm will learn as important features, so feature importances might be erroneous.
#
# ### - Interpretable Mimic Learning Framework (Che et al., 2016)
# - Borrow the ideas from knowledge distillation (Hinton, et al., 2015)
# - Use __Gradient boosting trees__ to mimic deep learning models:

# %%
Image(filename='.img/interpdl.png')

# %% [markdown]
# - Benefits: Good performance, less overfitting, interpretations via partial dependencies or feature importances
#   - Partial dependency plots
#     - Intrinsic sensitivity analysis
#   - Most useful decision trees
#     - Extract useful features

# %% [markdown]
# ## Takeaways for State Farm
#
# Healthcare is obviously similar to insurance in the sense that it's extremely regulated, as well. The medical domain suffers the same issue of interpretability, but seems to have far surpassed us in modeling complexity due to our risk aversion. They've shown that deep neural networks can be used in an interpretable sense. *We need to explore leveraging __mimic models__ in conjunction with more complex modeling*
